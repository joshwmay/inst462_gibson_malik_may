# %%
import pandas as pd

# %%
dat = pd.read_csv("master_clean.csv")
citiesdat = pd.read_csv("uscities.csv")

# %%
dat['Join'] = dat['b_city_x'] + dat['b_state_x']

# %%
citiesdat['Join'] = citiesdat['city'] + citiesdat['state_name']
citiesdat = citiesdat[['Join', 'lat', 'lng']]

# %%
pd.merge()
# Out:
#                                       Join      lat       lng
# 0                    South CreekWashington  46.9994 -122.3921
# 1                         RoslynWashington  47.2507 -121.0989
# 2                        SpragueWashington  47.3048 -117.9713
# 3                     Gig HarborWashington  47.3352 -122.5968
# 4                   Lake CassidyWashington  48.0639 -122.0920
# 5                         TeninoWashington  46.8537 -122.8607
# 6                      JamestownWashington  48.1229 -123.0911
# 7                    Three LakesWashington  47.9420 -121.9924
# 8                    Curlew LakeWashington  48.7311 -118.6663
# 9                     Chain LakeWashington  47.9038 -121.9861
# 10                       PaterosWashington  48.0536 -119.8994
# 11                       RosburgWashington  46.3076 -123.6344
# 12                      ParklandWashington  47.1417 -122.4376
# 13                     Birch BayWashington  48.9230 -122.7543
# ...
